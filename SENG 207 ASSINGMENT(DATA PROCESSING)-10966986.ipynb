# %%
import pandas as pd

# %%
data=pd.read_csv('data (2).csv')

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ### CHECKING FOR NULL SPACES

# %%
print(data.isnull().sum())
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
mean_pH= data.pH.mean()
mean_A = data.alcohol.mean()
mean_Q= data.quality.mean()
mean_D = data.density.mean()
mean_FA = data['fixed acidity'].mean()
mean_C = data.chlorides.mean()
mean_CA = data['citric acid'].mean()
mean_FSD   = data['free sulfur dioxide'].mean()
mean_TSD   = data['total sulfur dioxide'].mean()

# %%
mean_pH
# Out:
# 3.3111062500000004

# %%
mean_A
# Out:
# 10.42320424734541

# %%
mean_Q
# Out:
# 5.63625

# %%
mean_D
# Out:
# 0.9967456437500002

# %%
mean_FA
# Out:
# 8.319875000000001

# %%
mean_C
# Out:
# 0.0874874843554443

# %%
mean_CA
# Out:
# 0.271175

# %%
mean_FSD
# Out:
# 15.886875

# %%
mean_TSD
# Out:
# 46.52

# %%
print(f'{mean_pH} is the mean of pH')
print(f'{mean_A} is the mean of alchol')
print(f'{mean_Q} is the mean of quality')
print(f'{mean_D} is the mean of density')
print(f'{mean_FA} is the mean of fixed acidity ')
print(f'{mean_C} is the mean of  chlorides ')
print(f'{mean_CA} is the mean of citic acid ')
print(f'{mean_FSD} is the mean of free sulfur dioxide ')
print(f'{mean_TSD} is the mean of Total sulfur dioxide ')
# Out:
# 3.3111062500000004 is the mean of pH
# 10.42320424734541 is the mean of alchol
# 5.6362499999999995 is the mean of quality
# 0.9967456437500001 is the mean of density
# 8.319875 is the mean of fixed acidity
# 0.0874874843554443 is the mean of  chlorides
# 0.27117500000000005 is the mean of citic acid
# 15.886875 is the mean of free sulfur dioxide
# 46.52 is the mean of Total sulfur dioxide

# %%
data.pH = data3.pH.fillna(mean_pH)
data.alchol = data3.alcohol.fillna(mean_A)
data.density = data3.density.fillna(mean_D) 
data.quality = data3.quality.fillna(mean_Q)
data['fixed acidity']= data3['fixed acidity'].fillna(mean_FA)
data.chlorides = data3.chlorides.fillna(mean_C)
data['citric acid'] = data3['citric acid'].fillna(mean_CA)
data['free sulfur dioxide'] =data3['free sulfur dioxide'].fillna(mean_FSD)

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density        pH  \
# ...

# %%
data.pH = round(data3.pH.fillna(mean_pH),3)
data.alchol=round(data3.alcohol.fillna(mean_A),3)
data.density=round(data3.density.fillna(mean_D),3)
data.quality=round(data3.quality.fillna(mean_Q),3)
data['fixed acidity']=round(data3['fixed acidity'].fillna(mean_FA),3)
data.chlorides=round(data3.chlorides.fillna(mean_C),3)
data['citric acid']=round(data3['citric acid'].fillna(mean_CA),3)
data['free sulfur dioxide'] =round(data3['free sulfur dioxide'].fillna(mean_FSD),3)
data['total sulfur dioxide'] =round(data3['total sulfur dioxide'].fillna(mean_TSD),3)

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  \
# ...

# %% [markdown]
# ### CHECKING FOR NULL SPACES AFTER DATA PROCESSING

# %%
print(data.isnull().sum())
# Out:
# ID                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### DATA FILE

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  \
# ...

# %%
data.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %%
data['ID'].describe()
# Out:
# count    1601.000000
# mean      801.000000
# std       462.313206
# min         1.000000
# 25%       401.000000
# 50%       801.000000
# 75%      1201.000000
# max      1601.000000
# Name: ID, dtype: float64

# %%
data['fixed acidity'].describe()
# Out:
# count    1601.000000
# mean        8.319875
# std         1.739495
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
data['volatile acidity'].describe()
# Out:
# count    1601.000000
# mean        0.527742
# std         0.178981
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %%
data['citric acid'].describe()
# Out:
# count    1601.000000
# mean        0.271175
# std         0.194684
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
data['residual sugar'].describe()
# Out:
# count    1601.000000
# mean        2.538445
# std         1.409138
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %%
data['chlorides'].describe()
# Out:
# count    1601.000000
# mean        0.087487
# std         0.047032
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
data['free sulfur dioxide'].describe()
# Out:
# count    1601.000000
# mean       15.886875
# std        10.455218
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
data['total sulfur dioxide'].describe()
# Out:
# count    1601.000000
# mean       46.520000
# std        32.967416
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
data['density'].describe()
# Out:
# count    1601.000000
# mean        0.996742
# std         0.001889
# min         0.990000
# 25%         0.996000
# 50%         0.997000
# 75%         0.998000
# max         1.004000
# Name: density, dtype: float64

# %%
data['pH'].describe()
# Out:
# count    1601.000000
# mean        3.311106
# std         0.154290
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
data['sulphates'].describe()
# Out:
# count    1601.000000
# mean        0.658220
# std         0.169471
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
data['alcohol'].describe()
# Out:
# count    1601.000000
# mean       10.423204
# std         1.065495
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
data['quality'].describe()
# Out:
# count    1601.000000
# mean        5.636250
# std         0.807116
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %% [markdown]
# ###  DATA CORRELATION AMONG COLUMNS

# %%
data.corr()
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.267899         -0.009544    -0.153293
# fixed acidity        -0.267899       1.000000         -0.255557     0.670856
# volatile acidity     -0.009544      -0.255557          1.000000    -0.552909
# citric acid          -0.153293       0.670856         -0.552909     1.000000
# residual sugar       -0.031589       0.114595          0.001877     0.143517
# chlorides            -0.119157       0.093484          0.060768     0.203971
# free sulfur dioxide   0.091145      -0.152932         -0.010591    -0.061251
# total sulfur dioxide -0.113809      -0.113325          0.076247     0.036014
# density              -0.372455       0.665820          0.019043     0.364479
# pH                    0.135083      -0.682452          0.235182    -0.542636
# sulphates            -0.124243       0.182291         -0.261364     0.312840
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(data.corr(), cmap='Greens', interpolation='none')
plt.colorbar()
plt.xticks(range(len(data.corr())), data.corr().columns, rotation=90)
plt.yticks(range(len(data.corr())), data.corr().columns)
plt.show()

# %%
data.plot(kind='bar', x='free sulfur dioxide', y='total sulfur dioxide')

plt.title('Bar Chart of free sulfur dioxidea against total sulfur dioxide ')
plt.xlabel('free sulfur dioxide')
plt.ylabel('total sulfur dioxide')
plt.xticks(rotation=45)

plt.show()
